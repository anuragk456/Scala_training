// %%
case class Student(sno: Int, name: String, score: Int) {
  override def toString: String = {
    s"Student(SNo: $sno, Name: $name, Score: $score)"
  }
}

implicit class EnhancedStudent(val student: Student) {
  def rangeFinder(): String = {
    if (student.score > 70 && student.score <= 100)
      "60-100"
    else if (student.score <60 && student.score >= 0)
      "less then 60"
    else
      "Invalid"
  }
}

val students = List(
  Student(1, "Alice", 71),
  Student(2, "Bob", 75),
  Student(3, "Charlie", 55),
  Student(4, "David", 45)
)

students.foreach { student =>
  println(student)
  println(s"Score range: ${student.rangeFinder()}")
  println()
}
// Out:
// Student(SNo: 1, Name: Alice, Score: 71)
// Score range: 70-100
//
// Student(SNo: 2, Name: Bob, Score: 75)
// Score range: 70-100
//
// Student(SNo: 3, Name: Charlie, Score: 55)
// Score range: Less than 60
//
// Student(SNo: 4, Name: David, Score: 45)
// Score range: Less than 60
//
// Student(SNo: 5, Name: Anurag, Score: -10)
// Score range: Invalid
// defined class Student
// defined class EnhancedStudent
// students: List[Student] = List(
//   Student(sno = 1, name = "Alice", score = 71),
//   Student(sno = 2, name = "Bob", score = 75),
//   Student(sno = 3, name = "Charlie", score = 55),
//   Student(sno = 4, name = "David", score = 45),
//   Student(sno = 5, name = "Anurag", score = -10)
// )

// %%
case class Student(sno: Int, name: String, score: Int) {
  override def toString: String = {
    s"Student(SNo: $sno, Name: $name, Score: $score)"
  }
}

implicit class EnhancedStudent(val student: Student) {
    def #%(score: Int): List = 
  def rangeFinder(): String = {
    if (student.score > 70 && student.score <= 100)
      "70-100"
    else if (student.score < 60 && student.score >= 0)
      "Less than 60"
    else
      "Invalid"
  }
}

val students = List(
  Student(1, "Alice", 71),
  Student(2, "Bob", 75),
  Student(3, "Charlie", 55),
  Student(4, "David", 45),
  Student(5, "Anurag", -10)
)

students.foreach { student =>
  val enhancedStudent = new EnhancedStudent(student)
  println(student)
  println(s"Score range: ${enhancedStudent.rangeFinder()}")
  println()
}

// %%
case class Student(sno: Int, name: String, score: Int) {
  override def toString: String = {
    s"Student(SNo: $sno, Name: $name, Score: $score)"
  }
}

implicit class EnhancedList(val students: List[Student]) {
  def %>(threshold: Int): List[Student] = {
    students.filter(_.score > threshold)
  }
  
  def %<(threshold: Int): List[Student] = {
    students.filter(_.score <= threshold)
  }
}

val students = List(
  Student(1, "Alice", 71),
  Student(2, "Bob", 75),
  Student(3, "Charlie", 55),
  Student(4, "David", 45)
)

// val studentsAbove70 = students.%>(70)
// val studentsBelow60 = students.%<(60)

val studentsAbove70 = students %> 70
val studentsBelow60 = students %< 60

println("Students with scores greater than 70:")
studentsAbove70.foreach(println)

println("\nStudents with scores less than or equal to 60:")
studentsBelow60.foreach(println)
// Out:
// Students with scores greater than 70:
// Student(SNo: 1, Name: Alice, Score: 71)
// Student(SNo: 2, Name: Bob, Score: 75)
//
// Students with scores less than or equal to 60:
// Student(SNo: 3, Name: Charlie, Score: 55)
// Student(SNo: 4, Name: David, Score: 45)
// defined class Student
// defined class EnhancedList
// students: List[Student] = List(
//   Student(sno = 1, name = "Alice", score = 71),
//   Student(sno = 2, name = "Bob", score = 75),
//   Student(sno = 3, name = "Charlie", score = 55),
//   Student(sno = 4, name = "David", score = 45)
// )
// studentsAbove70: List[Student] = List(
//   Student(sno = 1, name = "Alice", score = 71),
//   Student(sno = 2, name = "Bob", score = 75)
// )
// studentsBelow60: List[Student] = List(
//   Student(sno = 3, name = "Charlie", score = 55),
//   Student(sno = 4, name = "David", score = 45)
// )

// %%
case class Student(sno: Int, name: String, score: Int) {
  override def toString: String = {
    s"Student(SNo: $sno, Name: $name, Score: $score)"
  }
}

implicit def typeConversion(tuple: (Int, String, Int)): Student = {
  Student(tuple._1, tuple._2, tuple._3)
}

val students = List(
  Student(1, "Alice", 71),
  Student(2, "Bob", 75),
  Student(3, "Charlie", 55),
  Student(4, "David", 45)
)

// for(x <- students){
//   println(x);
// }


val s1 = (5, "Eve", 80);
val s2 = (6, "Eren", 30);
val newS1: Student = typeConversion(s1);
val newS2: Student = typeConversion(s2);

val studentList = students :+ newS1 :+ newS2;

println("Updated list of students:")
for (x <- studentList) {
  println(x)
}
// Out:
// cmd14.sc:7: implicit conversion method typeConversion should be enabled
// by making the implicit value scala.language.implicitConversions visible.
// This can be achieved by adding the import clause 'import scala.language.implicitConversions'
// or by setting the compiler option -language:implicitConversions.
// See the Scaladoc for value scala.language.implicitConversions for a discussion
// why the feature should be explicitly enabled.
// implicit def typeConversion(tuple: (Int, String, Int)): Student = {
//              ^
// Updated list of students:
// Student(SNo: 1, Name: Alice, Score: 71)
// Student(SNo: 2, Name: Bob, Score: 75)
// Student(SNo: 3, Name: Charlie, Score: 55)
// Student(SNo: 4, Name: David, Score: 45)
// Student(SNo: 5, Name: Eve, Score: 80)
// Student(SNo: 6, Name: Eren, Score: 30)
// defined class Student
// defined function typeConversion
// students: List[Student] = List(
//   Student(sno = 1, name = "Alice", score = 71),
// ...

// %%
case class Student(sno: Int, name: String, score: Int) {
  override def toString: String = {
    s"Student(SNo: $sno, Name: $name, Score: $score)"
  }
}

implicit def typeConversion(tuple: (Int, String, Int)): Student = {
  Student(tuple._1, tuple._2, tuple._3)
}

object StudentOps {
  private var students: List[Student] = List()

  def add(newStudentTuple: (Int, String, Int)): Unit = {
    val newStudent = typeConversion(newStudentTuple)
    students :+= newStudent
  }

  def printStudents(): Unit = {
    println("List of Students:")
    students.foreach(println)
  }
}

val initialStudents = List(
  Student(1, "Alice", 71),
  Student(2, "Bob", 75),
  Student(3, "Charlie", 55),
  Student(4, "David", 45)
)

initialStudents.foreach(student => StudentOps.add((student.sno, student.name, student.score)))

StudentOps.add((5, "Eve", 80))
StudentOps.add((6, "Eren", 30))

StudentOps.printStudents()
// Out:
// cmd16.sc:7: implicit conversion method typeConversion should be enabled
// by making the implicit value scala.language.implicitConversions visible.
// This can be achieved by adding the import clause 'import scala.language.implicitConversions'
// or by setting the compiler option -language:implicitConversions.
// See the Scaladoc for value scala.language.implicitConversions for a discussion
// why the feature should be explicitly enabled.
// implicit def typeConversion(tuple: (Int, String, Int)): Student = {
//              ^
// List of Students:
// Student(SNo: 1, Name: Alice, Score: 71)
// Student(SNo: 2, Name: Bob, Score: 75)
// Student(SNo: 3, Name: Charlie, Score: 55)
// Student(SNo: 4, Name: David, Score: 45)
// Student(SNo: 5, Name: Eve, Score: 80)
// Student(SNo: 6, Name: Eren, Score: 30)
// defined class Student
// defined function typeConversion
// defined object StudentOps
// initialStudents: List[Student] = List(
//   Student(sno = 1, name = "Alice", score = 71),
// ...

// %%
case class Student(sno: Int, name: String, score: Int) {
  override def toString: String = {
    s"Student(SNo: $sno, Name: $name, Score: $score)"
  }
}

implicit def typeConversion(tuple: (Int, String, Int)): Student = {
  Student(tuple._1, tuple._2, tuple._3)
}

object StudentOps {
  private var students: List[Student] = List()

  def add(newStudentTuple: (Int, String, Int)): Unit = {
    val newStudent = typeConversion(newStudentTuple)
    students :+= newStudent
  }

  def add(student: Student): Unit = {
    students :+= student
  }

  def printStudents(): Unit = {
    println("List of Students:")
    students.foreach(println)
  }
}

val initialStudents = List(
  Student(1, "Alice", 71),
  Student(2, "Bob", 75),
  Student(3, "Charlie", 55),
  Student(4, "David", 45)
)

initialStudents.foreach(student => StudentOps.add((student.sno, student.name, student.score)))

StudentOps.add((5, "Eve", 80))
StudentOps.add((6, "Eren", 30))
StudentOps.add(Student(7, "Anurag Kurmi", 40))
StudentOps.printStudents()
// Out:
// cmd17.sc:7: implicit conversion method typeConversion should be enabled
// by making the implicit value scala.language.implicitConversions visible.
// This can be achieved by adding the import clause 'import scala.language.implicitConversions'
// or by setting the compiler option -language:implicitConversions.
// See the Scaladoc for value scala.language.implicitConversions for a discussion
// why the feature should be explicitly enabled.
// implicit def typeConversion(tuple: (Int, String, Int)): Student = {
//              ^
// List of Students:
// Student(SNo: 1, Name: Alice, Score: 71)
// Student(SNo: 2, Name: Bob, Score: 75)
// Student(SNo: 3, Name: Charlie, Score: 55)
// Student(SNo: 4, Name: David, Score: 45)
// Student(SNo: 5, Name: Eve, Score: 80)
// Student(SNo: 6, Name: Eren, Score: 30)
// Student(SNo: 7, Name: Anurag Kurmi, Score: 40)
// defined class Student
// defined function typeConversion
// defined object StudentOps
// initialStudents: List[Student] = List(
// ...

// %%
case class Student(sno: Int, name: String, score: Int) {
  override def toString: String = {
    s"Student(SNo: $sno, Name: $name, Score: $score)"
  }
}

val records = Array(
  (1, "Alice", 85), (2, "Bob", 92), (3, "Charlie", 78), (4, "David", 66), (5, "Eve", 90),
  (6, "Frank", 73), (7, "Grace", 88), (8, "Hannah", 91), (9, "Isaac", 84), (10, "Judy", 76),
  (11, "Kevin", 82), (12, "Laura", 79), (13, "Mike", 95), (14, "Nina", 70), (15, "Oscar", 89),
  (16, "Paul", 80), (17, "Quinn", 77), (18, "Rachel", 93), (19, "Sam", 85), (20, "Tina", 74),
  (21, "Uma", 69), (22, "Victor", 96), (23, "Wendy", 87), (24, "Xander", 68), (25, "Yara", 94),
  (26, "Zane", 81), (27, "Oliver", 78), (28, "Sophia", 85), (29, "Liam", 90), (30, "Mia", 83),
  (31, "Noah", 88), (32, "Emma", 75), (33, "Ava", 92), (34, "William", 86), (35, "James", 91),
  (36, "Lucas", 72), (37, "Amelia", 79), (38, "Ella", 89), (39, "Mason", 76), (40, "Logan", 95),
  (41, "Ethan", 84), (42, "Charlotte", 82), (43, "Benjamin", 80), (44, "Alexander", 71),
  (45, "Michael", 88), (46, "Isabella", 73), (47, "Daniel", 86), (48, "Elijah", 81),
  (49, "Matthew", 79), (50, "Jackson", 92)
)

val students: Array[Student] = records.map { case (sno, name, score) => Student(sno, name, score) }


// implicit def arrayToList(students: Array[Student]): List[Student] = {
//   students.toList
// }

implicit class EnhancedArray(val arr: Array[Student]) {
  def filterList(x: Student => Boolean): List[Student] = {
    arr.filter(x).toList
  }
}

val listRes = students.filterList(student => student.score > 50)
for (x <- listRes) {
  println(x)
}
// Out:
// cmd30.sc:24: implicit conversion method arrayToList should be enabled
// by making the implicit value scala.language.implicitConversions visible.
// This can be achieved by adding the import clause 'import scala.language.implicitConversions'
// or by setting the compiler option -language:implicitConversions.
// See the Scaladoc for value scala.language.implicitConversions for a discussion
// why the feature should be explicitly enabled.
// implicit def arrayToList(students: Array[Student]): List[Student] = {
//              ^
// java.lang.StackOverflowError
//   ammonite.$sess.cmd30$Helper.arrayToList(cmd30.sc:25)
//   ammonite.$sess.cmd30$Helper.arrayToList(cmd30.sc:25)
//   ammonite.$sess.cmd30$Helper.arrayToList(cmd30.sc:25)
//   ammonite.$sess.cmd30$Helper.arrayToList(cmd30.sc:25)
//   ammonite.$sess.cmd30$Helper.arrayToList(cmd30.sc:25)
//   ammonite.$sess.cmd30$Helper.arrayToList(cmd30.sc:25)
//   ammonite.$sess.cmd30$Helper.arrayToList(cmd30.sc:25)
// ...
