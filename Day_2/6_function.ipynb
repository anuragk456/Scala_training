// %%
def process(x: String): String = s"Process $x has started";

val target = process _;
val copy: String => String = process;

println(target("ABC"));
println(copy("DEF"));
// Out:
// Process ABC has started
// Process DEF has started
// defined function process
// target: String => String = ammonite.$sess.cmd1$Helper$$Lambda/0x000000040120d800@3552cfca
// copy: String => String = ammonite.$sess.cmd1$Helper$$Lambda/0x000000040120dbc0@4b4204bf

// %%
def process(x: String) = s"Process $x has started";

val target = process _;
val copy: String => String = process;

println(target("ABC"));
println(copy("DEF"));
// Out:
// Process ABC has started
// Process DEF has started
// defined function process
// target: String => String = ammonite.$sess.cmd4$Helper$$Lambda/0x0000000401912210@2baf3b27
// copy: String => String = ammonite.$sess.cmd4$Helper$$Lambda/0x00000004019125d0@27c5bc52
